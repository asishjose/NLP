# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("google-t5/t5-small")
model = AutoModelForSeq2SeqLM.from_pretrained("google-t5/t5-small")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# ...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/131 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
text = "translate English to German: I love machine learning"

inputs = tokenizer(text, return_tensors='pt')

outputs =  model.generate(**inputs)

result = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(result)
# Out:
# Ich liebe das Maschinenlernen

# %%
text = "translate German to English: Ich liebe das Maschinenlernen"

inputs = tokenizer(text, return_tensors='pt')

outputs =  model.generate(**inputs)

result = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(result)
# Out:
# Ich liebe das Maschinenlernen

# %%
text = "question: Who discovered gravity? context: Isaac Newton formulated the law of gravity."

inputs = tokenizer(text, return_tensors='pt')

outputs =  model.generate(**inputs)

result = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(result)
# Out:
# Isaac Newton

# %%
text = "fix grammar: She go to school yesterday"
inputs = tokenizer(text, return_tensors='pt')

outputs =  model.generate(**inputs)

result = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(result)
# Out:
# she went to school yesterday

# %%
sentences = [
    "translate English to German: I like pizza",
    "translate English to German: Deep learning is powerful"
]

inputs = tokenizer(
    sentences,
    return_tensors="pt",
    padding=True
)

outputs = model.generate(**inputs)

for o in outputs:
    print(tokenizer.decode(o, skip_special_tokens=True))
# Out:
# Ich mag Pizza
# Tiefes Lernen ist mächtig

# %%
outputs = model.generate(
    **inputs,
    max_length=50,
    num_beams=4,
    early_stopping=True
)

for o in outputs:
    print(tokenizer.decode(o, skip_special_tokens=True))
# Out:
# Ich mag Pizza
# Tiefes Lernen ist mächtig

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "facebook/nllb-200-distilled-600M"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

text = "Machine learning is very powerful"

inputs = tokenizer(text, return_tensors="pt")

outputs = model.generate(
    **inputs,
    forced_bos_token_id=tokenizer.lang_code_to_id["hin_Deva"]
)

print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 5
#       1 from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
#       3 model_name = "facebook/nllb-200-distilled-600M"
# ----> 5 tokenizer = AutoTokenizer.from_pretrained(model_name)
#       6 model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
#       8 text = "Machine learning is very powerful"
#
# File ~/AI-ML/venv/lib/python3.12/site-packages/transformers/models/auto/tokenization_auto.py:644, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     635         tokenizer_auto_map = tokenizer_config["auto_map"].get("AutoTokenizer", None)
# ...
