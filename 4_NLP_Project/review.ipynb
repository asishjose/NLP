# %%
import spacy
nlp = spacy.load("en_core_web_sm")

text = " My name is Asish."


doc = nlp(text)

for d in doc:
    print(d.label_, d.entity_)

# %%
for d in doc:
    print(nlp.label_,)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 for d in doc.label:
#       2     print( doc)
#
# AttributeError: 'spacy.tokens.doc.Doc' object has no attribute 'label'

# %%
doc.ent
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 doc.ent
#
# AttributeError: 'spacy.tokens.doc.Doc' object has no attribute 'ent'
