# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/nlp_sample_dataset.csv')
df.head()
# Out:
#    id                                               text     label
# 0   1  I absolutely loved this movie! The acting was ...  positive
# 1   2  The film was too long and boring. I almost fel...  negative
# 2   3  Great visuals, but the plot didn’t make much s...   neutral
# 3   4  An outstanding performance by the lead actor. ...  positive
# 4   5  Terrible experience. The screenplay was weak a...  negative

# %%
df.shape
# Out:
# (15, 3)

# %%
import nltk
import spacy
import re
import contractions

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
stop_words = stopwords.words('english')

# %%
lemmatizer = WordNetLemmatizer()

# %%
def preprocess(text):
    text = text.lower()
    text = contractions.fix(text)
    text = re.sub(r'W+', " ", text)
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    return ' '.join(tokens)

# %%
df['clean_text'] = df['text'].apply(preprocess)

# %%
df['clean_text']
# Out:
# 0     absolutely loved movie ! acting brilliant stor...
# 1       film long boring . almost fell asleep halfway .
# 2                great visuals , plot make much sense .
# 3     outstanding performance lead actor . truly ins...
# 4     terrible experience . screenplay weak dialogue...
# 5     movie exceeded expectation . well directed emo...
# 6             bad , could much better tighter editing .
# 7     amazing soundtrack cinematography . story dece...
# 8     would recommend movie . lacked originality dep...
# 9        masterpiece ! one best film seen recent year .
# 10          pacing slow , performance kept interested .
# 11    poor character development ruined could good m...
# 12              entertaining watch predictable moment .
# 13          movie potential , execution disappointing .
# 14    fantastic storytelling strong emotional connec...
# Name: clean_text, dtype: str

# %%
sample = df['text'][0]

# %%
sample
# Out:
# 'I absolutely loved this movie! The acting was brilliant and the story was engaging.'

# %%
word_tokens = word_tokenize(sample)
word_tokens
# Out:
# ['I',
#  'absolutely',
#  'loved',
#  'this',
#  'movie',
#  '!',
#  'The',
#  'acting',
#  'was',
#  'brilliant',
#  'and',
#  'the',
#  'story',
#  'was',
#  'engaging',
#  '.']

# %%
sent_tokens = sent_tokenize(sample)
sent_tokens
# Out:
# ['I absolutely loved this movie!',
#  'The acting was brilliant and the story was engaging.']

# %%
vectorizer = TfidfVectorizer()

# %%
X_tfidf = vectorizer.fit_transform(df['clean_text'])

# %%
from gensim.models import Word2Vec

# %%
embedding = Word2Vec(
    sentences=documents,
    vector_size = 100,
    window=5,
    min_count=1,
    workers=4,
    sg = 1
)

# %%
vector = model.wv["product"]
print(vector.shape)  
print(vector[:10])
